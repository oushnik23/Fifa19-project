# %% [markdown]
# <a href="https://colab.research.google.com/github/oushnik23/Fifa19-project/blob/main/fifa_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
fifa=pd.read_csv("fifa19.csv")
fifa.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4169 entries, 0 to 4168
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                4169 non-null   int64
#  1   ID                        4169 non-null   int64
#  2   Name                      4169 non-null   object
#  3   Age                       4169 non-null   int64
#  4   Photo                     4169 non-null   object
#  5   Nationality               4169 non-null   object
#  6   Flag                      4169 non-null   object
#  7   Overall                   4169 non-null   int64
#  8   Potential                 4169 non-null   int64
#  9   Club                      4111 non-null   object
#  10  Club Logo                 4169 non-null   object
#  11  Value                     4169 non-null   object
#  12  Wage                      4169 non-null   object
#  13  Special                   4168 non-null   float64
#  14  Preferred Foot            4168 non-null   object
#  15  International Reputation  4168 non-null   float64
#  16  Weak Foot                 4168 non-null   float64
#  17  Skill Moves               4168 non-null   float64
#  18  Work Rate                 4168 non-null   object
#  19  Body Type                 4168 non-null   object
#  20  Real Face                 4168 non-null   object
#  21  Position                  4168 non-null   object
#  22  Jersey Number             4168 non-null   float64
#  23  Joined                    3792 non-null   object
#  24  Loaned From               318 non-null    object
#  25  Contract Valid Until      4110 non-null   object
#  26  Height                    4168 non-null   object
#  27  Weight                    4168 non-null   object
#  28  LS                        3791 non-null   object
#  29  ST                        3791 non-null   object
#  30  RS                        3791 non-null   object
#  31  LW                        3791 non-null   object
#  32  LF                        3791 non-null   object
#  33  CF                        3791 non-null   object
#  34  RF                        3791 non-null   object
#  35  RW                        3791 non-null   object
#  36  LAM                       3791 non-null   object
#  37  CAM                       3791 non-null   object
#  38  RAM                       3791 non-null   object
#  39  LM                        3791 non-null   object
#  40  LCM                       3791 non-null   object
#  41  CM                        3791 non-null   object
#  42  RCM                       3791 non-null   object
#  43  RM                        3791 non-null   object
#  44  LWB                       3791 non-null   object
#  45  LDM                       3791 non-null   object
#  46  CDM                       3791 non-null   object
#  47  RDM                       3791 non-null   object
#  48  RWB                       3791 non-null   object
#  49  LB                        3791 non-null   object
#  50  LCB                       3791 non-null   object
#  51  CB                        3791 non-null   object
#  52  RCB                       3791 non-null   object
#  53  RB                        3791 non-null   object
#  54  Crossing                  4168 non-null   float64
#  55  Finishing                 4168 non-null   float64
#  56  HeadingAccuracy           4168 non-null   float64
#  57  ShortPassing              4168 non-null   float64
#  58  Volleys                   4168 non-null   float64
#  59  Dribbling                 4168 non-null   float64
#  60  Curve                     4168 non-null   float64
#  61  FKAccuracy                4168 non-null   float64
#  62  LongPassing               4168 non-null   float64
#  63  BallControl               4168 non-null   float64
#  64  Acceleration              4168 non-null   float64
#  65  SprintSpeed               4168 non-null   float64
#  66  Agility                   4168 non-null   float64
#  67  Reactions                 4168 non-null   float64
#  68  Balance                   4168 non-null   float64
#  69  ShotPower                 4168 non-null   float64
#  70  Jumping                   4168 non-null   float64
#  71  Stamina                   4168 non-null   float64
#  72  Strength                  4168 non-null   float64
#  73  LongShots                 4168 non-null   float64
#  74  Aggression                4168 non-null   float64
#  75  Interceptions             4168 non-null   float64
#  76  Positioning               4168 non-null   float64
#  77  Vision                    4168 non-null   float64
#  78  Penalties                 4168 non-null   float64
#  79  Composure                 4168 non-null   float64
#  80  Marking                   4168 non-null   float64
#  81  StandingTackle            4168 non-null   float64
#  82  SlidingTackle             4168 non-null   float64
#  83  GKDiving                  4168 non-null   float64
#  84  GKHandling                4168 non-null   float64
#  85  GKKicking                 4168 non-null   float64
#  86  GKPositioning             4168 non-null   float64
#  87  GKReflexes                4168 non-null   float64
#  88  Release Clause            3790 non-null   object
# dtypes: float64(39), int64(5), object(45)
# memory usage: 2.8+ MB

# %%
fifa.describe()
# Out:
#         Unnamed: 0             ID  ...  GKPositioning   GKReflexes
# count  4169.000000    4169.000000  ...    4168.000000  4168.000000
# mean   2084.000000  199310.622931  ...      16.442658    16.650672
# std    1203.630965   31432.796747  ...      18.756791    19.469453
# min       0.000000      16.000000  ...       1.000000     1.000000
# 25%    1042.000000  187132.000000  ...       8.000000     8.000000
# 50%    2084.000000  203668.000000  ...      11.000000    11.000000
# 75%    3126.000000  219841.000000  ...      14.000000    14.000000
# max    4168.000000  246403.000000  ...      90.000000    94.000000
#
# [8 rows x 44 columns]

# %%
fifa[fifa.Nationality=='India']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []
#
# [0 rows x 89 columns]

# %%
fifa[fifa.Club=='Manchester United']
# Out:
#       Unnamed: 0      ID  ... GKReflexes  Release Clause
# 3              3  193080  ...       94.0         €138.6M
# 45            45  195864  ...        3.0         €123.2M
# 47            47  192505  ...       10.0         €120.3M
# 93            93  184941  ...       13.0          €69.4M
# 116          116  211300  ...       11.0          €87.1M
# 132          132  191202  ...        9.0          €44.4M
# 211          211  178088  ...        8.0          €45.3M
# 250          250  209297  ...       15.0            €51M
# 254          254  207494  ...        9.0            €51M
# 319          319  231677  ...       14.0          €55.4M
# 327          327  225508  ...        8.0          €43.1M
# 374          374  191740  ...        8.0          €32.4M
# 377          377  189881  ...       15.0          €30.8M
# 399          399  167905  ...        7.0          €18.5M
# 454          454  205988  ...        7.0          €31.8M
# 526          526  173373  ...       82.0          €16.7M
# 584          584  221660  ...        9.0          €29.7M
# 629          629  201862  ...       10.0          €18.5M
# 654          654  194957  ...       11.0          €23.1M
# 700          700  176944  ...       16.0          €21.3M
# 717          717  152908  ...       15.0            €13M
# 807          807  208450  ...        7.0          €28.7M
# 1313        1313  184392  ...        7.0          €11.1M
# 2561        2561   53739  ...       76.0           €2.5M
# 3451        3451  234574  ...        8.0           €9.6M
#
# [25 rows x 89 columns]

# %%
fifa[fifa.Club=='FC Barcelona']['Name']
# Out:
# 0              L. Messi
# 7             L. Suárez
# 18        M. ter Stegen
# 20      Sergio Busquets
# 32             Coutinho
# 42            S. Umtiti
# 49           Jordi Alba
# 53           I. Rakitić
# 54                Piqué
# 96             A. Vidal
# 155          O. Dembélé
# 192       Sergi Roberto
# 228              Arthur
# 236              Malcom
# 239          C. Lenglet
# 263             Rafinha
# 266        J. Cillessen
# 324       Nélson Semedo
# 613        Denis Suárez
# 1007              Munir
# 1037       T. Vermaelen
# 3118       Sergi Samper
# 3684              Aleñá
# Name: Name, dtype: object

# %% [markdown]
# ***Deleting unwanted columns***

# %%
fifa=fifa.drop(['Unnamed: 0','Club Logo','Jersey Number','Photo','Joined','Special','Loaned From','Body Type', 'Release Clause','Weight','Height','Contract Valid Until'],axis=1)

# %%
fifa.drop_duplicates(subset="Name", inplace=True)

# %%
fifa.rename(columns={'Preferred Foot':'Preferred_foot'},inplace=True)

# %%
fifa.isnull().sum()
# Out:
# ID               0
# Name             0
# Age              0
# Nationality      0
# Flag             0
#                 ..
# GKDiving         1
# GKHandling       1
# GKKicking        1
# GKPositioning    1
# GKReflexes       1
# Length: 77, dtype: int64

# %%
figure=plt.figure(figsize=(14,10))
sns.heatmap(fifa.isnull(),cmap='coolwarm')

# %%
fifa['Club']=fifa.Club.fillna('No Club')
fifa['Position']=fifa.Position.fillna('Unknown')
fifa['Preferred_foot']=fifa.Preferred_foot.fillna(fifa.Preferred_foot.mode()[0])

# %%
fifa1=fifa.dropna(axis=0,how='any')

# %%
fifa1.isnull().any()
# Out:
# ID               False
# Name             False
# Age              False
# Nationality      False
# Flag             False
#                  ...
# GKDiving         False
# GKHandling       False
# GKKicking        False
# GKPositioning    False
# GKReflexes       False
# Length: 77, dtype: bool

# %%
len(fifa)-len(fifa1)
# Out:
# 372

# %%
print("Total no of club {0}".format(fifa1['Club'].nunique()))
# Out:
# Total no of club 456

# %%
print("Total no of country {0}".format(fifa1['Nationality'].nunique()))
# Out:
# Total no of country 115

# %%
print("Maximum Overall : {0} ".format(fifa.loc[fifa['Overall'].idxmax()][1]))
# Out:
# Maximum Overall : L. Messi

# %%
print("Maximum Potential : " +str(fifa1.loc[fifa1['Potential'].idxmax()][1]))
# Out:
# Maximum Potential : K. Mbappé

# %%
col=['Crossing','Finishing','Overall','Stamina']
i=0;
while i<len(col):
  print("Best {0}: {1}".format(col[i],fifa1.loc[fifa1[col[i]].idxmax()][1]))
  i+=1
# Out:
# Best Crossing: K. De Bruyne
# Best Finishing: L. Messi
# Best Overall: L. Messi
# Best Stamina: N. Kanté

# %%
sns.barplot(data=fifa1,x='Overall',y='Club')

# %%
fifa1['Value'].unique()
# Out:
# array(['€110.5M', '€77M', '€118.5M', '€102M', '€93M', '€67M', '€80M',
#        '€51M', '€76.5M', '€44M', '€60M', '€63M', '€89M', '€83.5M', '€78M',
#        '€51.5M', '€64.5M', '€27M', '€81M', '€69.5M', '€59.5M', '€62M',
#        '€73.5M', '€59M', '€46M', '€43M', '€57M', '€24M', '€64M', '€62.5M',
#        '€52M', '€38M', '€45M', '€34M', '€46.5M', '€61M', '€44.5M',
#        '€56.5M', '€53M', '€50M', '€55M', '€36.5M', '€45.5M', '€43.5M',
#        '€35M', '€30M', '€39M', '€18M', '€21.5M', '€50.5M', '€54M',
#        '€40.5M', '€37.5M', '€28.5M', '€37M', '€26M', '€30.5M', '€33M',
#        '€38.5M', '€35.5M', '€9M', '€15.5M', '€22M', '€14M', '€32M',
#        '€42.5M', '€31.5M', '€42M', '€29.5M', '€31M', '€24.5M', '€27.5M',
#        '€25M', '€29M', '€16.5M', '€23M', '€4.2M', '€40M', '€41M', '€28M',
#        '€22.5M', '€34.5M', '€32.5M', '€20M', '€26.5M', '€19M', '€25.5M',
#        '€21M', '€17.5M', '€11.5M', '€8M', '€6.5M', '€20.5M', '€23.5M',
#        '€18.5M', '€19.5M', '€17M', '€12.5M', '€15M', '€4.8M', '€16M',
#        '€13M', '€11M', '€7M', '€14.5M', '€10M', '€13.5M', '€5.5M', '€6M',
#        '€10.5M', '€4.5M', '€12M', '€0', '€9.5M', '€8.5M', '€1.7M',
#        '€3.6M', '€7.5M', '€3.8M', '€4M', '€5M', '€2.9M', '€4.7M', '€4.1M',
#        '€2.1M', '€2.7M', '€3.4M', '€2.5M', '€3.2M', '€3.1M', '€4.3M',
#        '€2.3M', '€3.9M', '€3M', '€2.2M', '€4.4M', '€4.9M', '€900K',
#        '€3.7M', '€3.5M', '€1.6M', '€1.9M', '€2M', '€450K', '€775K',
#        '€2.4M', '€650K', '€2.8M', '€4.6M', '€1.3M', '€750K', '€2.6M',
#        '€1.2M', '€1.8M', '€3.3M', '€950K', '€550K', '€1.1M', '€1.5M',
#        '€270K', '€975K', '€1.4M', '€425K', '€725K', '€875K', '€675K',
#        '€1M', '€325K', '€800K', '€850K'], dtype=object)

# %% [markdown]
# **As the 2 columns Value and Wages both are having '€','M','K' signs so we need to remove those signs and show as M=100000, k=1000**

# %%
def value_and_wage_conversion(Value):
  if isinstance(Value,str):
    out=Value.replace('€','')
    if 'M' in out:
      out=float(out.replace('M',''))*100000
    elif 'K' in Value:
      out=float(out.replace('K',''))*1000
    return float(out)

# %%
fifa1['Value']=fifa1['Value'].apply(lambda x: value_and_wage_conversion(x))
fifa1['Wage']=fifa1['Wage'].apply(lambda x: value_and_wage_conversion(x))

# %%
fifa1['Value']
# Out:
# 0       11050000.0
# 1        7700000.0
# 2       11850000.0
# 4       10200000.0
# 5        9300000.0
#            ...
# 4163      950000.0
# 4164      350000.0
# 4165      180000.0
# 4166      260000.0
# 4167      725000.0
# Name: Value, Length: 3699, dtype: float64

# %%
fifa1['Wage']
# Out:
# 0       565000.0
# 1       405000.0
# 2       290000.0
# 4       355000.0
# 5       340000.0
#           ...
# 4163      4000.0
# 4164      7000.0
# 4165     13000.0
# 4166     14000.0
# 4167      9000.0
# Name: Wage, Length: 3699, dtype: float64

# %%
fifa1["Work Rate"]
# Out:
# 0       Medium/ Medium
# 1            High/ Low
# 2         High/ Medium
# 4           High/ High
# 5         High/ Medium
#              ...
# 4163    Medium/ Medium
# 4164        High/ High
# 4165      High/ Medium
# 4166    Medium/ Medium
# 4167      Medium/ High
# Name: Work Rate, Length: 3699, dtype: object

# %%
temp=fifa1['Work Rate'].str.split('/',n=1,expand=True)

# %%
fifa1['Work Rate1']=temp[0]
fifa1['Work Rate2']=temp[1]

# %%
fifa1['Work Rate2']
# Out:
# 0        Medium
# 1           Low
# 2        Medium
# 4          High
# 5        Medium
#          ...
# 4163     Medium
# 4164       High
# 4165     Medium
# 4166     Medium
# 4167       High
# Name: Work Rate2, Length: 3699, dtype: object

# %%
fifa1['Preferred_foot'].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %% [markdown]
# **Taking the value for Preferred_foot column as Binary**

# %%
fifa1['Preferred_foot']=fifa1['Preferred_foot'].replace('Right',1)
fifa1['Preferred_foot']=fifa1['Preferred_foot'].replace('Left',0)

# %% [markdown]
# **Taking the value for Real face column as Binary**

# %%
fifa1['Real Face']=fifa1['Real Face'].replace('Yes',1)
fifa1['Real Face']=fifa1['Real Face'].replace('No',0)

# %% [markdown]
# **Checking the Data type for Position column**

# %%
fifa1['Position'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
#             ...
# 4163    <class 'str'>
# 4164    <class 'str'>
# 4165    <class 'str'>
# 4166    <class 'str'>
# 4167    <class 'str'>
# Name: Position, Length: 3699, dtype: object

# %% [markdown]
# **Creating simple_position column containing only standarised position as GK, CD(Central Defender),CM(Central Midfielder), CDM(Central Defender Midfielder), AM(Attacking Midfielder), ST(Striker)**

# %%
def simple_position(fifa1):
    if(fifa1['Position']=='GK'):
        return 'GK'
    elif ((fifa1['Position']=='RWB')|(fifa1['Position']=='LWB')|(fifa1['Position']=='CB')|(fifa1['Position']=='LB')|(fifa1['Position']=='RB')|(fifa1['Position']=='RCB')|(fifa1['Position']=='LCB')) :
        return 'CD'
    elif ((fifa1['Position']=='LCM')|(fifa1['Position']=='RCM')|(fifa1['Position']=='CM')|(fifa1['Position']=='LM')|(fifa1['Position']=='RM')):
        return 'CM'
    elif ((fifa1['Position']=='LDM')|(fifa1['Position']=='RDM')|(fifa1['Position']=='CDM')):
        return 'CDM'
    elif ((fifa1['Position']=='CAM')|(fifa1['Position']=='RAM')|(fifa1['Position']=='LAM')):
        return 'AM'
    elif ((fifa1['Position']=='RF')|(fifa1['Position']=='ST')|(fifa1['Position']=='LF')|(fifa1['Position']=='LW')|(fifa1['Position']=='RS')|(fifa1['Position']=='RW')|(fifa1['Position']=='CF')):
        return 'ST'
    else:
        return fifa1.Position

# %%
fifa1['Simple_Position']=fifa.apply(simple_position,axis=1)

# %%
fifa1['Simple_Position'].unique()
# Out:
# array(['ST', 'CM', 'CD', 'CDM', 'AM', 'LS'], dtype=object)

# %%
fifa1=fifa1.drop(['LS','ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM','LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB','LCB', 'CB', 'RCB', 'RB','Flag','Work Rate','Position'],axis=1)

# %% [markdown]
# **Dividing the 'fifa1' dataset into dependent and independent variables**

# %%
x=fifa1.drop(['Overall','Name','Nationality','Club'], axis=1)
y=fifa1['Overall']

# %% [markdown]
# **One Hot Encoding for categorical columns**

# %%
x=pd.get_dummies(x)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2)

# %%
from sklearn.linear_model import LinearRegression
lr_model=LinearRegression()
lr_model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
prediction=lr_model.predict(xtest)
np.set_printoptions(precision=0)
print(np.concatenate((prediction.reshape(len(prediction),1),ytest.values.reshape(len(ytest),1)),1))
# Out:
# [[82. 83.]
#  [76. 77.]
#  [74. 75.]
#  ...
#  [78. 78.]
#  [73. 73.]
#  [82. 83.]]

# %%
from sklearn.metrics import r2_score 
print("R2 Score : {:.2f}".format(r2_score(ytest,prediction)*100))
# Out:
# R2 Score : 90.16

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(X=xtrain,y=ytrain,cv=10,estimator=lr_model)
print("Accuracy {:.2f} :".format(score.mean()*100))
print("Standard deviation {0}".format(score.std()*100))
# Out:
# Accuracy 90.67 :
# Standard deviation 0.8552825138995749

# %%
from sklearn.tree import DecisionTreeRegressor
dte=DecisionTreeRegressor()
dte.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dte.predict(xtest)

# %%
print("R2_score: {:.2f}%".format(r2_score(ytest,y_pred)*100))
# Out:
# R2_score: 97.36%

# %%
score=cross_val_score(X=xtrain,y=ytrain,cv=10,estimator=dte)

# %%
print("Standard deviation is {:.2f}%".format(score.std()*100))
print("cross val score {:.2f}%".format(score.mean()*100))
# Out:
# Standard deviation is 0.88%
# cross val score 96.61%

# %%
print(dte.feature_importances_)
# Out:
# [3.e-04 6.e-02 7.e-02 8.e-01 4.e-03 0.e+00 0.e+00 5.e-05 0.e+00 8.e-05
#  3.e-04 1.e-03 4.e-04 1.e-03 4.e-04 2.e-05 2.e-04 2.e-04 2.e-04 5.e-04
#  8.e-05 2.e-04 2.e-05 2.e-02 6.e-05 2.e-04 3.e-04 2.e-04 1.e-04 6.e-04
#  7.e-05 8.e-04 3.e-04 5.e-05 3.e-04 2.e-04 2.e-03 3.e-03 1.e-02 1.e-04
#  2.e-04 0.e+00 1.e-04 1.e-04 2.e-05 6.e-06 3.e-05 2.e-04 2.e-05 0.e+00
#  5.e-05 2.e-04 2.e-05 0.e+00 0.e+00 0.e+00]

# %%
plt.figure(figsize=(12,12))
imp=pd.Series(dte.feature_importances_,index=x.columns)
imp.nlargest(x.shape[1]).plot(kind='barh')
